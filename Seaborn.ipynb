# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
anagrams = sns.load_dataset('anagrams')
anscombe = sns.load_dataset('anscombe')
attention = sns.load_dataset('attention')
brain_networks = sns.load_dataset('brain_networks')
car_crashes = sns.load_dataset('car_crashes')
diamonds = sns.load_dataset('diamonds')
dots = sns.load_dataset('dots')
dowjones = sns.load_dataset('dowjones')
exercise = sns.load_dataset('exercise')
flights = sns.load_dataset('flights')
fmri = sns.load_dataset('fmri')
geyser = sns.load_dataset('geyser')
glue = sns.load_dataset('glue')
healthexp = sns.load_dataset('healthexp')
iris = sns.load_dataset('iris')
mpg = sns.load_dataset('mpg')
penguins = sns.load_dataset('penguins')
planets = sns.load_dataset('planets')
seaice = sns.load_dataset('seaice')
taxis = sns.load_dataset('taxis')
tips = sns.load_dataset('tips')
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.scatterplot(x='tip', y='total_bill', data=tips, hue='day', size = 'size', palette='YlGnBu')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
# Load the dataset
anscombe = sns.load_dataset('anscombe')

# Plot each dataset
sns.lmplot(data=anscombe, x="x", y="y", col="dataset", hue="dataset",
            col_wrap=2, ci=None, palette="muted", height=4,
            scatter_kws={"s": 50, "alpha": 0.7})

plt.show()

# Display the first few rows
print(anscombe.head())

# Information about the dataset
print(anscombe.info())
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB
# None

# %%
sns.histplot(tips['tip'], kde=True, bins=15)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.distplot(tips['tip'], kde=True, bins=15)
# Out:
# <ipython-input-21-b9468442975b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['tip'], kde=True, bins=15)
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.barplot(x='sex', y='tip', data=tips, palette="YlGnBu")
# Out:
# <ipython-input-23-ba0270c78e55>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='sex', y='tip', data=tips, palette="YlGnBu")
# <Axes: xlabel='sex', ylabel='tip'>

# %%
# Load the "tips" dataset
tips = sns.load_dataset("tips")

# Explore the dataset
print(tips.head())

# Create a visualization
sns.barplot(x="day", y="total_bill", data=tips)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='tip', data=tips, palette="YlGnBu", hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x='day', y='tip', data=tips, palette="YlGnBu", hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='reg')

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='kde', shade=True, cmap="YlGnBu")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='hex', cmap="YlGnBu")

# %%
sns.pairplot(titanic.select_dtypes(['number']), hue='pclass')

# %%
sns.heatmap(titanic.select_dtypes(['number']).corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
sns.heatmap(titanic.select_dtypes(['number']).corr(), annot=True, cmap="icefire")
# Out:
# <Axes: >

# %%
sns.clustermap(iris.drop("species", axis=1))

# %%
pip install openpyxl

# %%
mart = pd.read_excel("supermarket_sales.xlsx")
mart.head()
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
# ...

# %%
mart = pd.read_excel("supermarket_sales.xlsx")
mart
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 0    692-92-5582      B  Mandalay        Member  Female
# 1    351-62-0822      B  Mandalay        Member  Female
# 2    529-56-3974      B  Mandalay        Member    Male
# 3    299-46-1805      B  Mandalay        Member  Female
# 4    319-50-3348      B  Mandalay        Normal  Female
# ..           ...    ...       ...           ...     ...
# 995  886-18-2897      A    Yangon        Normal  Female
# 996  745-74-0715      A    Yangon        Normal    Male
# 997  727-02-1313      A    Yangon        Member    Male
# 998  347-56-2442      A    Yangon        Normal    Male
# 999  849-09-3807      A    Yangon        Member  Female
#
#                Product line  Unit price  Quantity  Tax 5%    Total  \
# 0        Food_and_beverages       54.84         3   8.226  172.746
# 1       Fashion_accessories       14.48         4   2.896   60.816
# 2    Electronic_accessories       25.51         4   5.102  107.142
# ...

# %%
mart = pd.read_excel("supermarket_sales.xlsx")
mart.head()
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
# ...

# %%
sns.countplot(x='Gender', data=mart, palette="YlGnBu")
# Out:
# <ipython-input-20-fc65d5514375>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=mart, palette="YlGnBu")
# <Axes: xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product line', data=mart, palette="hsv")
# Out:
# <ipython-input-29-facf6b64e511>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Product line', data=mart, palette="hsv")
# <Axes: xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(y='Product line', data=mart, palette="hsv")
# Out:
# <ipython-input-30-15fc66fd2cb4>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Product line', data=mart, palette="hsv")
# <Axes: xlabel='count', ylabel='Product line'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product line', hue='Gender', data=mart, palette="hsv")
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product line', hue='Gender', data=mart, palette="gist_gray")
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product line', hue='Gender', data=mart, palette="PuBuGn_r")
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product line', data=mart,
              facecolor=(1, 0, 1, 0),
              linewidth=5,
              edgecolor=sns.color_palette('dark', 3))
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line', y='Total', data=mart, palette="deep")
# Out:
# <ipython-input-13-1a96579febff>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Product line', y='Total', data=mart, palette="deep")
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line', y='Total', hue='Gender', data=mart, palette="dark")
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Total', y='Product line', hue='Gender', data=mart, palette="dark")
# Out:
# <Axes: xlabel='Total', ylabel='Product line'>

# %%
x = mart['Product line'].sort_values()
x.unique()
# Out:
# array(['Electronic_accessories', 'Fashion_accessories',
#        'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
#        'Sports_and_travel'], dtype=object)

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line', y='Total', hue='Gender', data=mart, palette="YlGnBu", order=['Electronic_accessories', 'Fashion_accessories',
       'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
       'Sports_and_travel'], hue_order=['Male', 'Female'])
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line', y='Total', hue='Gender', data=mart, palette="YlGnBu", order=['Electronic_accessories', 'Fashion_accessories',
       'Food_and_beverages', 'Health_and_beauty', 'Home_and_lifestyle',
       'Sports_and_travel'], hue_order=['Male', 'Female'], capsize=0.2)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>
